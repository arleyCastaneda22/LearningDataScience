# %%
import pandas as pd

import numpy as np

u =np.array([1,0])
v=np.array([0,1])
z=u+v

print(z)
# Out:
# [1 1]

# %%
u =np.array( [[1,2,3,4], [1,2,3,5],[1,2,3,4]] )
print(u)
print(u.size)
print(u.ndim)
print(u.shape)

print(u[2][1:4])
# Out:
# [[1 2 3 4]
#  [1 2 3 5]
#  [1 2 3 4]]
# 12
# 2
# (3, 4)
# [2 3 4]

# %%
a=np.array([0,1])

b=np.array([1,0])

z= np.dot(a,b)
print(z)
# Out:
# 0

# %%
A=['1','2','3']

for a in A:

    print(2*a)
# Out:
# 11
# 22
# 33
